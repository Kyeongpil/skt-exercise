# %%
from konlpy.tag import Twitter
from sklearn.decomposition import NMF
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.preprocessing import normalize
from scipy.sparse import dok_matrix
from collections import Counter
import numpy as np
import json
import pickle

twitter = Twitter()

# %%
with open("data/preprocessed_data.pkl", 'rb') as f:
    preprocessed_data = pickle.load(f)

# %%
preprocessed_data.keys()
# Out:
# dict_keys(['index2voca', 'voca2index', 'wordsList', 'tdm', 'raw_text'])

# %%
preprocessed_data['wordsList'][0]
# Out:
# ['칼럼',
#  '친일',
#  '독재',
#  '잔치',
#  '끝나다',
#  '승인',
#  '노동자',
#  '투쟁',
#  '연대',
#  '대표',
#  '근혜',
#  '순실',
#  '시대',
#  '국정',
#  '농단',
#  '부역',
#  '들이다',
#  '정권',
#  '탄핵',
#  '레짐',
#  '구체제',
#  '촛불',
#  '항쟁',
#  '부딪치다',
#  '역사',
#  '일단락',
#  '이제',
#  '다음',
#  '단계',
#  '무소',
#  '불위',
#  '권력',
#  '두르다',
#  '국민',
#  '권력',
#  '상실',
#  '형사',
#  '소추',
#  '대상',
#  '박근혜',
#  '구속',
#  '여부',
#  '적폐',
#  '청산',
#  '박근혜',
#  '일가',
#  '대다',
#  '영화',
#  '교차',
#  '오버',
#  '필자',
#  '상한',
#  '마약',
#  '혐의',
#  '구속',
#  '남동생',
#  '민영화',
#  '저지',
#  '발전',
#  '파업',
#  '구속',
#  '여러',
#  '차례',
#  '대화',
#  '나누다',
#  '동기',
#  '사이',
#  '지칭',
#  '두둔',
#  '태극기',
#  '집회',
#  '에서',
#  '망언',
#  '일삼',
#  '까지',
#  '친일',
#  '독재',
#  '다운',
#  '면모',
#  '위대하다',
#  '아버지',
#  '다카',
#  '마사',
#  '후광',
#  '빛나다',
#  '퇴진',
#  '투쟁',
#  '흔하다',
#  '없다',
#  '필자',
#  '엇갈리다',
#  '현대',
#  '사오다',
#  '회한',
#  '사무',
#  '치다',
#  '대비',
#  '극단',
#  '아버지',
#  '필자',
#  '선친',
#  '공교',
#  '태어나다',
#  '박정희',
#  '각하',
#  '일제',
#  '강점',
#  '다카',
#  '마사',
#  '혈서',
#  '충성',
#  '맹세',
#  '만주',
#  '학교',
#  '일본',
#  '졸업',
#  '군대',
#  '장교',
#  '출신',
#  '이후',
#  '지다',
#  '생명력',
#  '권력',
#  '정수',
#  '보이다',
#  '끝내',
#  '쿠데타',
#  '통해',
#  '최고',
#  '권좌',
#  '오른',
#  '통치',
#  '각하',
#  '공과',
#  '설명',
#  '무엇',
#  '심지어',
#  '대통령',
#  '대한민국',
#  '최고',
#  '명문',
#  '아니다',
#  '친일',
#  '독재',
#  '시대',
#  '받다',
#  '사람',
#  '대다',
#  '충성',
#  '모르다',
#  '얼마나',
#  '자랑스럽다',
#  '타다',
#  '주년',
#  '행사',
#  '대대',
#  '기다',
#  '설명',
#  '필요없다',
#  '친일파',
#  '일제',
#  '강점',
#  '끝나다',
#  '여년',
#  '이나',
#  '누린',
#  '영화',
#  '자랑스럽다',
#  '역사',
#  '전승',
#  '마당',
#  '말다',
#  '친일파',
#  '독재정',
#  '아바타',
#  '대다',
#  '세다',
#  '세상',
#  '반면',
#  '선친',
#  '선구자',
#  '이언',
#  '선생',
#  '후손',
#  '선생',
#  '손자',
#  '임진왜란',
#  '이순신',
#  '장군',
#  '까지',
#  '싸우다',
#  '조정',
#  '부르다',
#  '않다',
#  '마감',
#  '이의',
#  '후손',
#  '이의',
#  '장군',
#  '지은',
#  '의정',
#  '정자',
#  '직접',
#  '심다',
#  '지난',
#  '지금',
#  '고향',
#  '마을',
#  '정정',
#  '선생',
#  '집안',
#  '어르신',
#  '필자',
#  '고향',
#  '마을',
#  '에서',
#  '잡히다',
#  '해산',
#  '당하다',
#  '다시',
#  '결집',
#  '일제',
#  '싸우다',
#  '의병',
#  '전원',
#  '당하다',
#  '고향',
#  '에서',
#  '견디다',
#  '필자',
#  '만주',
#  '가다',
#  '만주',
#  '에서',
#  '무장',
#  '항일',
#  '투쟁',
#  '독립운동가',
#  '동생',
#  '어머니',
#  '선친',
#  '에서',
#  '결혼',
#  '시키다',
#  '해방',
#  '필자',
#  '중국',
#  '남다',
#  '어머니',
#  '조용하다',
#  '달래다',
#  '선친',
#  '이해',
#  '기다',
#  '세월',
#  '필요하다',
#  '대부분',
#  '집안',
#  '이름',
#  '대가',
#  '고생',
#  '경로',
#  '그대로',
#  '여년',
#  '흘르다',
#  '찢어지다',
#  '가난',
#  '유산',
#  '유일',
#  '상속',
#  '원망',
#  '않다',
#  '시대',
#  '집안',
#  '이지',
#  '다만',
#  '왜곡',
#  '역사',
#  '당당하다',
#  '조절',
#  '힘들다',
#  '마약',
#  '사범',
#  '파란',
#  '빛나다',
#  '박정희',
#  '각하',
#  '아들',
#  '감옥',
#  '에서',
#  '만나다',
#  '박근혜',
#  '대통령',
#  '회한',
#  '사무',
#  '치다',
#  '입안',
#  '에서',
#  '돌다',
#  '나라',
#  '늘다',
#  '촛불',
#  '한반도',
#  '밝히다',
#  '무렵',
#  '국민',
#  '에서',
#  '터지다',
#  '나오다',
#  '적폐',
#  '청산',
#  '구호',
#  '광화문',
#  '네거리',
#  '걸다',
#  '이번',
#  '역사',
#  '바로',
#  '세워지다',
#  '기르다',
#  '소리',
#  '빌다',
#  '빌다',
#  '조카',
#  '바르다',
#  '역사',
#  '물다',
#  '상속',
#  '시키다',
#  '않다',
#  '기르다',
#  '소리',
#  '없다',
#  '울음',
#  '염원',
#  '세상',
#  '달리',
#  '일이',
#  '없다',
#  '거리',
#  '나서다',
#  '외치다',
#  '레짐',
#  '역사',
#  '바로',
#  '기록',
#  '교육',
#  '노동자',
#  '민중',
#  '기본권',
#  '오다',
#  '나라',
#  '사람',
#  '사람',
#  '살다',
#  '나라',
#  '노동자',
#  '나라',
#  '부르다',
#  '나라',
#  '촛불',
#  '항쟁',
#  '명예혁명',
#  '이기',
#  '빌다',
#  '빌다',
#  '비정상',
#  '친일',
#  '독재',
#  '아바타',
#  '박근혜',
#  '파면',
#  '우주',
#  '기운',
#  '부정',
#  '축재',
#  '권력',
#  '농단',
#  '삼다',
#  '순실',
#  '시대',
#  '가다',
#  '일제',
#  '강점',
#  '기르다',
#  '포함',
#  '청산',
#  '우리',
#  '부끄럽다',
#  '시대',
#  '말다',
#  '지탄',
#  '역사',
#  '평가',
#  '청산',
#  '현실',
#  '미래',
#  '지향',
#  '설계',
#  '이어지다',
#  '기대하다',
#  '정치',
#  '통한',
#  '대통',
#  '울다',
#  '노동자',
#  '민중',
#  '가슴',
#  '투쟁',
#  '역사',
#  '전승',
#  '바란',
#  '구체제',
#  '독립운동가',
#  '희생',
#  '모독',
#  '불복종',
#  '태극기',
#  '흔들다',
#  '대도',
#  '새롭다',
#  '사회',
#  '신체',
#  '형성',
#  '과정',
#  '멈추다',
#  '레짐',
#  '촛불',
#  '항쟁',
#  '없다',
#  '끝나다',
#  '역사',
#  '분별',
#  '이어진',
#  '시대',
#  '청산',
#  '과정',
#  '에서',
#  '불가피하다',
#  '소음',
#  '감내하다',
#  '새롭다',
#  '시대',
#  '열리다',
#  '현대',
#  '사의',
#  '적폐',
#  '레짐',
#  '얼굴',
#  '박근혜',
#  '역사',
#  '강물',
#  '미련',
#  '흘리다',
#  '보내다',
#  '세기',
#  '동안',
#  '친일',
#  '독재',
#  '행태',
#  '극복',
#  '눈물',
#  '흘리다',
#  '모든',
#  '희생',
#  '헌신',
#  '따뜻하다',
#  '박수',
#  '노동자',
#  '투쟁',
#  '연대',
#  '대표',
#  '저작권',
#  '매일',
#  '노동',
#  '다른',
#  '대한',
#  '댓글',
#  '이야기',
#  '자동',
#  '등록',
#  '방지',
#  '코드',
#  '입력',
#  '확인',
#  '까지',
#  '쓸다',
#  '현재',
#  '최대',
#  '욕설',
#  '인신공격',
#  '삭제',
#  '대한',
#  '댓글',
#  '이야기']

# %%
preprocessed_data['index2voca'][12]
# Out:
# '기대'

# %%
# NMF
K = 10
nmf = NMF(n_components=K, max_iter=1000, alpha=0.1)
W = nmf.fit_transform(preprocessed_data['tdm'])
H = nmf.components_

# 각 토픽별 키워드 출력
for k in range(K):
    print(f"{k}th topic")
    for index in H[k].argsort()[::-1][:20]:
        print(preprocessed_data['index2voca'][index], end=" ")
    print("\n")
# Out:
# 0th topic
# 대통령 박근혜 청와대 탄핵 파면 삼성동 사저 서울 에서 헌법재판소 결정 인용 지지자 오후 받다 떠나다 않다 입장 대한 검찰
#
# 1th topic
# 대표 민주당 대선 에서 문재인 후보 더불다 지사 주자 경선 탈당 국민의당 안희정 정당 이재명 바르다 개헌 토론회 김종인 통합
#
# 2th topic
# 에서 탄핵 집회 서울 열리다 오후 박근혜 태극기 광장 광화문 반대 참가자 경찰 국민 촛불집회 퇴진 기각 행동 운동 촉구
#
# 3th topic
# 시간 대선 지원 출마 억원 보통사람 인상 소환 청춘 황교안 검찰 정부 금리 공개 변경 주택 문재인 한국 이상 출시
#
# 4th topic
# 탄핵 선고 심판 헌재 헌법재판소 결정 대통령 인용 재판관 박근혜 오전 기각 대한 결과 국회 평의 앞두다 최종 사건 이후
#
# 5th topic
# 국민 않다 없다 우리 에서 대한민국 아니다 결정 헌재 정치 탄핵 사람 생각 헌법 통합 지금 촛불 사회 민주주의 국가
#
# 6th topic
# 대행 권한 대선 에서 출마 대통령 황교안 재판관 정미 선거 않다 후보 국정 결정 지정 관리 퇴임 선거일 까지 국무회의
#
# 7th topic
# 수사 특검 검찰 대통령 결과 발표 받다 조사 혐의 에서 없다 최순실 박영수 않다 사실 대한 삼성 변호사 관련 사건
#
# 8th topic
# 의원 한국 자유 탄핵 정당 바르다 대선 에서 국회 지사 보수 출마 김진태 친박 위원장 후보 정치 밝히다 없다 선언
#
# 9th topic
# 에서 사드 중국 한국 정부 경제 배치 미국 상황 북한 않다 대한 정책 없다 관련 시장 따르다 문제 회의 정치

# %%
W.shape
# Out:
# (8805, 10)

# %%
from sklearn.manifold import TSNE

# select random index
selectNum = 2000
randIndex = np.random.choice(W.shape[0], selectNum, replace=False)
randIndex.sort()

# %%
tsne = TSNE(n_components=2, init='pca', verbose=1)
W2d = tsne.fit_transform(W[randIndex, :])
topicIndex = [v.argmax() for v in W[randIndex, :]]
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 2000 samples in 0.006s...
# [t-SNE] Computed neighbors for 2000 samples in 0.161s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2000
# [t-SNE] Computed conditional probabilities for sample 2000 / 2000
# [t-SNE] Mean sigma: 0.006748
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.397217
# [t-SNE] Error after 1000 iterations: 1.017929

# %%
W2d.shape
# Out:
# (2000, 2)

# %%
from bokeh.models import HoverTool
from bokeh.palettes import Category20
from bokeh.io import show, output_notebook
from bokeh.plotting import figure, ColumnDataSource
output_notebook()

# 사용할 툴들
tools_to_show = 'hover,box_zoom,pan,save,reset,wheel_zoom'
p = figure(plot_width=400, plot_height=300, tools=tools_to_show)

source = ColumnDataSource(data={
    'x': W2d[:, 0],
    'y': W2d[:, 1],
    'id': [i for i in randIndex],
    'document': [preprocessed_data['raw_text'][randInd][:100] for randInd in randIndex],  # 해당 기사
    'topic': [str(i) for i in topicIndex],  # 토픽 번호
    'color': [Category20[K][i] for i in topicIndex]
})
p.circle(
    'x', 'y',
    source=source,
    legend='topic',
    color='color',
    fill_alpha=0.7,
    line_alpha=0.7)

# 몇가지 interaction
p.legend.location = "top_left"
hover = p.select(dict(type=HoverTool))
hover.tooltips = [("Topic", "@topic"), ('id', '@id'), ("Article", "@document")]
hover.mode = 'mouse'

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="dc79ae61-efef-4f72-9f3d-d9fdfd14ad6f">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="21349435-3ecb-4135-90d0-1d9451c71060"></div>
# </div>
